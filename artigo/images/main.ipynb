# %%
sort_times = {
    "Bubble Sort": {
        "Invertidos": {
            750_000:  372_700,
            850_000:  483_917,
            950_000:  607_129,
            1_250_000: 1_084_873,
            1_350_000: 1_266_255,
        },
        "Ordenados": {
            750_000:  0,
            850_000:  0,
            950_000:  0,
            1_250_000: 0,
            1_350_000: 0,
        },
        "Randômicos": {
            750_000:  772_452,
            850_000:  997_231,
            950_000: 1_248_899,
            1_250_000: 2_181_504,
            1_350_000: 2_545_733,
        },
    },
    "Heap Sort": {
        "Invertidos": {
            750_000:  71,
            850_000:  79,
            950_000:  90,
            1_250_000: 113,
            1_350_000: 128,
        },
        "Ordenados": {
            750_000:  69,
            850_000:  71,
            950_000:  83,
            1_250_000: 111,
            1_350_000: 121,
        },
        "Randômicos": {
            750_000: 127,
            850_000: 144,
            950_000: 174,
            1_250_000: 228,
            1_350_000: 254,
        },
    },
    "Insertion Sort": {
        "Invertidos": {
            750_000:  218_781,
            850_000:  288_180,
            950_000:  362_907,
            1_250_000: 713_476,
            1_350_000: 785_191,
        },
        "Ordenados": {
            750_000:  0,
            850_000:  8,
            950_000:  0,
            1_250_000: 0,
            1_350_000: 0,
        },
        "Randômicos": {
            750_000: 107_056,
            850_000: 139_201,
            950_000: 175_981,
            1_250_000: 317_309,
            1_350_000: 373_832,
        },
    },
    "Merge Sort": {
        "Invertidos": {
            750_000:  132,
            850_000:  154,
            950_000:  180,
            1_250_000: 236,
            1_350_000: 253,
        },
        "Ordenados": {
            750_000:  132,
            850_000:  152,
            950_000:  172,
            1_250_000: 223,
            1_350_000: 246,
        },
        "Randômicos": {
            750_000: 191,
            850_000: 212,
            950_000: 253,
            1_250_000: 320,
            1_350_000: 348,
        },
    },
    "Quick Sort": {
        "Invertidos": {
            750_000:  48,
            850_000:  50,
            950_000:  61,
            1_250_000: 73,
            1_350_000: 83,
        },
        "Ordenados": {
            750_000:  40,
            850_000:  50,
            950_000:  61,
            1_250_000: 71,
            1_350_000: 72,
        },
        "Randômicos": {
            750_000: 78,
            850_000: 83,
            950_000: 101,
            1_250_000: 130,
            1_350_000: 141,
        },
    },
    "Radix Sort": {
        "Invertidos": {
            750_000:  99,
            850_000:  111,
            950_000:  130,
            1_250_000: 184,
            1_350_000: 203,
        },
        "Ordenados": {
            750_000:  90,
            850_000:  111,
            950_000:  122,
            1_250_000: 184,
            1_350_000: 203,
        },
        "Randômicos": {
            750_000:  97,
            850_000:  108,
            950_000:  131,
            1_250_000: 186,
            1_350_000: 202,
        },
    },
    "Selection Sort": {
        "Invertidos": {
            750_000:  216_295,
            850_000:  281_378,
            950_000:  357_546,
            1_250_000: 648_855,
            1_350_000: 764_995,
        },
        "Ordenados": {
            750_000:  214_557,
            850_000:  280_539,
            950_000:  357_921,
            1_250_000: 644_400,
            1_350_000: 755_976,
        },
        "Randômicos": {
            750_000:  216_323,
            850_000:  282_058,
            950_000:  357_819,
            1_250_000: 642_830,
            1_350_000: 755_743,
        },
    },
    "Shell Sort": {
        "Invertidos": {
            750_000:  40,
            850_000:  32,
            950_000:  50,
            1_250_000: 52,
            1_350_000: 64,
        },
        "Ordenados": {
            750_000:  22,
            850_000:  30,
            950_000:  30,
            1_250_000: 42,
            1_350_000: 50,
        },
        "Randômicos": {
            750_000: 130,
            850_000: 152,
            950_000: 172,
            1_250_000: 228,
            1_350_000: 255,
        },
    },
}

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

for algo, cenarios in sort_times.items():
    for nome, dados in cenarios.items():
        tamanhos = sorted(dados)
        tempos   = [dados[n] for n in tamanhos]
        plt.plot(tamanhos, tempos, marker='o', label=f"{algo} – {nome}")

plt.title("Comparação de Tempos de Ordenação")
plt.xlabel("Número de elementos")
plt.ylabel("Tempo (ms)")
plt.legend(ncol=2, fontsize="small")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

cenarios = ["Invertidos", "Ordenados", "Randômicos"]

for scenario in cenarios:
    plt.figure(figsize=(8, 5))
    for algo, dados_alg in sort_times.items():
        dados    = dados_alg[scenario]
        tamanhos = sorted(dados)
        tempos   = [dados[n] for n in tamanhos]
        plt.plot(tamanhos, tempos, marker='o', label=algo)
    plt.title(f"Tempos de Ordenação – {scenario}")
    plt.xlabel("Número de elementos")
    plt.ylabel("Tempo (ms)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
